# %%
#!pip install wellpathpy
#!pip install welly

# %% [markdown]
# ## Import the Required Libraries

# %%
from welly import Well
from welly import Curve

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and Explore Data from LAS File

# %%
well = Well.from_las('49025104000000_283139.LAS')
# Out:
# c:\users\banamz\appdata\local\programs\python\python39\lib\site-packages\welly\well.py:194: FutureWarning: From v0.5 the default will be 'original', keeping whatever is used in the LAS file. If you want to force conversion to metres, change your code to use `index='m'`.
#   warnings.warn(m, FutureWarning)

# %%
well
# Out:
# Well(uwi: '', 9 curves: ['SPR', 'MSFL', 'LLD', 'LLS', 'GRD', 'CALD', 'CORR', 'RHOB', 'NPHI'])

# %%
well.header
# Out:
# {'name': 'FENIX "AX" #85-10', 'uwi': '', 'field': 'NPR 3', 'api': '49025104000000', 'company': 'FENIX & SCISSON'}

# %%
well.header.name
# Out:
# 'FENIX "AX" #85-10'

# %%
well.header.field
# Out:
# 'NPR 3'

# %%
well.uwi
# Out:
# ''

# %%
well.count_curves()
# Out:
# 9

# %%
well._get_curve_mnemonics()
# Out:
# ['SPR', 'MSFL', 'LLD', 'LLS', 'GRD', 'CALD', 'CORR', 'RHOB', 'NPHI']

# %%
well.data
# Out:
# {'SPR': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'MSFL': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'LLD': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'LLS': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'GRD': Curve([82.903, 82.903, 82.903, ...,    nan,    nan,    nan]),
#  'CALD': Curve([nan, nan, nan, ..., nan, nan, nan]),
#  'CORR': Curve([-0.171, -0.171, -0.171, ...,    nan,    nan,    nan]),
#  'RHOB': Curve([2.217, 2.217, 2.217, ...,   nan,   nan,   nan]),
#  'NPHI': Curve([0.427, 0.427, 0.427, ..., 0.247, 0.247, 0.247])}

# %%
well.data['SPR']
# Out:
# Curve([nan, nan, nan, ..., nan, nan, nan])

# %%
well.data['RHOB']
# Out:
# Curve([2.217, 2.217, 2.217, ...,   nan,   nan,   nan])

# %%
well.data['GRD'].read_at(800)
# Out:
# 85.32880577428286

# %% [markdown]
# ## Welly Plotting

# %%
well.plot(extents='curve')

# %%
well.plot(tracks=['MD', 'GRD'])
# Out:
# c:\users\banamz\appdata\local\programs\python\python39\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
well.plot(tracks=['MD', 'GRD', 'RHOB'])
# Out:
# c:\users\banamz\appdata\local\programs\python\python39\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
well.plot(tracks=['MD', 'GRD', 'RHOB', ['LLD', 'LLS']])
# Out:
# c:\users\banamz\appdata\local\programs\python\python39\lib\site-packages\welly\well.py:593: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
well.data['GRD'].plot_kde()

# %%
well.data['GRD'].plot_2d()
